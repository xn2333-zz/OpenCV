# %% [markdown]
# <a href="https://colab.research.google.com/github/xn2333/OpenCV/blob/master/Seminar_Image_Processing_in_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Introduction to Image Processing in Python**
# An NCSU Libraries Workshop
#
# Speaker: Nian Xiong
#
# This workshop intends to provide some basic image processing techniques based on OpenCV library and some standard data analysis library of python. Knowledge of Python programming is not required for this seminar, but will help.
#
#
#
# ---
#
# Background: colab usage basics:
# https://colab.research.google.com/notebooks/welcome.ipynb

# %% [markdown]
# ##Step1: Load the Dependencies
#
# links of the libraries

# %%
import numpy as np # for linear algebra, Fourier transform, and random number capabilities
import pandas as pd # for data analysis
import cv2 as cv # for computer vision applications
from google.colab.patches import cv2_imshow # for image display
from skimage import io # for image processing applications
from PIL import Image # provides general image handeling and lots of useful basic image operations including 
from matplotlib.pylab import * # python plotting lib, providing object-oriented API for embedding plots

# %% [markdown]
# ##Step2: Read Image from Urls

# %%
# Create a list to store the strings of the urls of the images
urls = ["https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg",
       "https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg"]
        
# Read and display the image
# loop over the image URLs, you could store several image urls in the list

for url in urls:
  image = io.imread(url) 
  plt.figure(figsize=([10, 10]))
  plt.subplot(121), plt.imshow(image)
  plt.subplot(122), plt.imshow(cv.cvtColor(image, cv.COLOR_BGR2RGB))
  plt.show()

# %%
## TODO: LOAD IMAGE

# %% [markdown]
# ##Step3: Image Contours and Histograms

# %%
# Check the image matrix data type (could know the bit depth of the image)
image.dtype
# Check the image dimension
image.shape
# Out:
# (571, 800, 3)

# %%
from matplotlib.pylab import * 
hist(image.flatten(),128)
# Out:
# (array([9.0000e+00, 3.3000e+01, 2.2300e+02, 2.1950e+03, 1.3547e+04,
#         3.1325e+04, 3.5133e+04, 4.1144e+04, 5.0014e+04, 4.8457e+04,
#         4.1132e+04, 3.5232e+04, 3.0496e+04, 2.6510e+04, 2.4713e+04,
#         2.3386e+04, 2.1960e+04, 2.0685e+04, 2.0390e+04, 1.9361e+04,
#         1.8879e+04, 1.8565e+04, 1.7898e+04, 1.7137e+04, 1.7238e+04,
#         1.6852e+04, 1.6516e+04, 1.6601e+04, 1.6190e+04, 1.6484e+04,
#         1.6223e+04, 1.5664e+04, 1.5920e+04, 1.5435e+04, 1.4968e+04,
#         1.4911e+04, 1.4520e+04, 1.4620e+04, 1.4477e+04, 1.4206e+04,
#         1.4331e+04, 1.4170e+04, 1.4320e+04, 1.4827e+04, 1.4822e+04,
#         1.5284e+04, 1.5206e+04, 1.5293e+04, 1.5258e+04, 1.4608e+04,
#         1.4396e+04, 1.4268e+04, 1.3505e+04, 1.2996e+04, 1.2278e+04,
#         1.2129e+04, 1.1646e+04, 1.1304e+04, 1.1574e+04, 1.0890e+04,
#         1.0556e+04, 1.0479e+04, 1.0148e+04, 9.4940e+03, 9.2090e+03,
#         9.0600e+03, 8.7220e+03, 8.4830e+03, 7.9380e+03, 7.7830e+03,
#         7.2550e+03, 7.1470e+03, 7.1310e+03, 7.0840e+03, 6.9050e+03,
#         160.375    , 162.3046875, 164.234375 , 166.1640625, 168.09375  ,
#         170.0234375, 171.953125 , 173.8828125, 175.8125   , 177.7421875,
#         179.671875 , 181.6015625, 183.53125  , 185.4609375, 187.390625 ,
#         189.3203125, 191.25     , 193.1796875, 195.109375 , 197.0390625,
#         198.96875  , 200.8984375, 202.828125 , 204.7578125, 206.6875   ,
#         208.6171875, 210.546875 , 212.4765625, 214.40625  , 216.3359375,
#         218.265625 , 220.1953125, 222.125    , 224.0546875, 225.984375 ,
#         227.9140625, 229.84375  , 231.7734375, 233.703125 , 235.6328125,
#         237.5625   , 239.4921875, 241.421875 , 243.3515625, 245.28125  ,
#         247.2109375, 249.140625 , 251.0703125, 253.       ]),
#  <a list of 128 Patch objects>)

# %%
## TODO: GRAYIMAGE
## DISPLAY

# %%
contour(gray_image, origin = "image")

# %%
## TODO: CONTOUR

# %% [markdown]
# ##Step4: Grayscale Transform and Histogram Equalization
# ###Description: In image2, ....inverse

# %%
im2 = 255 - gray_image
cv2_imshow(im2)
# Out:
# <PIL.Image.Image image mode=L size=800x571 at 0x7F0D78B30F98>

# %% [markdown]
# ###Image 3 is to add a constant noise....(formula)....application....(purpose)...

# %% [markdown]
# Tranform: give a formula, they can implement...

# %%
im3 = (100.0/255)*gray_image + 100
cv2_imshow(im3)
# Out:
# <PIL.Image.Image image mode=L size=800x571 at 0x7F0D78B30E10>

# %%
im4 = 255.0*(gray_image/255.0)**2
cv2_imshow(im4)
# Out:
# <PIL.Image.Image image mode=L size=800x571 at 0x7F0D78B30DD8>

# %% [markdown]
# ### make better contrast ratio, histogram for each image...
# ### provide an overview
# ### find a new image to analyze

# %%
def histeq(im, nbr_bins = 256):
  """ Histogram equalization of a grayscale image.  """
  # get the image histogram
  imhist, bins = histogram(im.flatten(), nbr_bins, normed = True)
  cdf = imhist.cumsum() # cumulative distribution function
  cdf = 255*cdf/cdf[-1]  #normalize
  
  # use linear interpolation of cdf to find new pixel values
  #im2 = interp(im.flatten(), bins[-1], cdf)
  return im2.reshape(im.shape), cdf

im5, cdf = histeq(im4)
cv2_imshow(im5)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: VisibleDeprecationWarning: Passing `normed=True` on non-uniform bins has always been broken, and computes neither the probability density function nor the probability mass function. The result is only correct if the bins are uniform, when density=True will produce the same result anyway. The argument will be removed in a future version of numpy.
#   """
# <PIL.Image.Image image mode=L size=800x571 at 0x7F0D78B68978>

# %% [markdown]
# ### Exerceise: Find a new image from the following image database to do a histogram equalization and compare it with the original image to figure out the difference: https://d.lib.ncsu.edu/collections

# %%
## TODO: IMPLEMENT YOUR CODE HERE
## CODE INSTRUCTION
plt.imshow(im5)
##

# %% [markdown]
# ##Step5: Fourier Transform of Gray Images

# %%
f = np.fft.fft2(gray_image)
fshift = np.fft.fftshift(f)
magnitude_spectrum = 20*np.log(np.abs(fshift))

plt.subplot(121),plt.imshow(gray_image, cmap = 'gray')
plt.title('Input Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(magnitude_spectrum, cmap = 'gray')
plt.title('Magnitude Spectrum'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
## todo: the same thing

# %% [markdown]
# Make the images horizontal ...
# FFT....
# 30 min talk, 30 min questions, 30 min buffer time
# Add a description of what will be covered, 5 to 8 sentences. Send to Walt.

# %% [markdown]
# ## Step6: Edge detection by Highpass Filtering

# %%
rows, cols = gray_image.shape
crow,ccol = rows/2 , cols/2
f_ishift = np.fft.ifftshift(fshift)
img_back = np.fft.ifft2(f_ishift)
img_back = np.abs(img_back)

plt.figure(figsize=([20, 20]))
plt.subplot(131),plt.imshow(gray_image, cmap = 'gray')
plt.title('Input Image'), plt.xticks([]), plt.yticks([])
plt.subplot(132),plt.imshow(img_back, cmap = 'gray')
plt.title('Image after HPF'), plt.xticks([]), plt.yticks([])
plt.subplot(133),plt.imshow(img_back)
plt.title('Result in JET'), plt.xticks([]), plt.yticks([])
plt.show()
